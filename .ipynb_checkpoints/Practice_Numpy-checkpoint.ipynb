# %% [markdown]
# # DataScience
# 1. *Data Collection*
# 2. **Data Cleaning**
# 3. Data Analysis
# 4. Data Visualization
# 5. ## Data Pridection
#    1. Machine Learnig
#       ---------------
#    3. Deep Learning
#    4. GanAI
#    5. Agentic AI

# %%
a = 6

# %%
b = 7

# %%
print(c)
# Out:
# 7

# %%
c = 7
